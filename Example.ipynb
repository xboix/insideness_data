# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# SMALL IMAGE GENERATOR

# %%
#Generate Images
import small_images

im_sizes = [8, 12, 14, 18, 24, 42]
images = {}
for size in im_sizes:
    images[size] = small_images.make_small_images((size, size), 4)

# %%
#Plot one of the generated images

#Image
plt.figure()
plt.imshow(np.squeeze(images[42][0][0]), cmap='gray')    

#Ground-truth
plt.figure()
plt.imshow(np.squeeze(images[42][0][1]), cmap='gray')

# %% [markdown]
# LOAD DIGS AND SPIRAL DATASETS

# %%
with open('data/spiral.pkl', 'rb') as f:
    images = pickle.load(f)
    
#Image
plt.figure()
plt.imshow(np.squeeze(images['test_img'][0]), cmap='gray')    

#Ground-truth
plt.figure()
plt.imshow(np.squeeze(images['test_gt'][0]), cmap='gray')

# %%
with open('data/digs.pkl', 'rb') as f:
    images = pickle.load(f)
    
#Image
plt.figure()
plt.imshow(np.squeeze(images['test_img'][0]), cmap='gray')    

#Ground-truth
plt.figure()
plt.imshow(np.squeeze(images['test_gt'][0]), cmap='gray')
